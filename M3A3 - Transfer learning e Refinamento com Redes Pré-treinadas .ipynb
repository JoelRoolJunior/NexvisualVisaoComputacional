# %% [markdown]
# # M3A3 - Transfer learning e Refinamento com Redes Pré-treinadas

# %% [markdown]
# Na prática de hoje vamos refinar modelos de aprendizado profundo com [PyTorch](https://pytorch.org/).
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Carregar Base de Dados
# - Refinar Modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install torch torchvision

# %% [markdown]
# Importar as bibliotecas e Ler Imagens do Disco

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import torchvision

# %% [markdown]
# ## Carregar Base de Dados
#
# A primeira tarefa para refinar um modelo é criar a base de dados.

# %%
# Definir o pré-processamento dos dados.
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Resize(256),
                                            torchvision.transforms.CenterCrop(224)])

# Carregar o conjunto de treino.
train_data = torchvision.datasets.MNIST(
    root='./data',      # Pasta para salvar os dados.
    train=True,         # Busca pelo sub conjunto de treino.
    download=True,      # Download do dados se necessário.
    transform=transform # Transformação a ser aplicada.
)

# Carregar o conjunto de teste.
test_data = torchvision.datasets.MNIST(
    root='./data',      # Pasta para salvar os dados.
    train=False,        # Busca pelo sub conjunto de teste.
    download=True,      # Download do dados se necessário.
    transform=transform # Transformação a ser aplicada.
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
# Visualizar duas imagens aleatórias da base de dados.
indexes = [np.random.randint(0, len(train_data)), np.random.randint(0, len(train_data))]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
axes[0].imshow(train_data[indexes[0]][0].numpy().transpose(1,2,0), cmap="gray")
axes[1].imshow(train_data[indexes[1]][0].numpy().transpose(1,2,0), cmap="gray")
plt.show()

# %% [markdown]
# ## Refinar Modelo
#
# Agora vamos carregar o modelo e refinar.

# %%
# Carregar o modelo
vgg_16_model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)

# Vamos alterar a última camada.
num_classes = 10  # Número de classes na nova base.
in_features = vgg_16_model.classifier[6].in_features # Features que chegam na última camada.
vgg_16_model.classifier[6] = torch.nn.Linear(in_features, num_classes) # Substiu a última camada.

# Vamos alterar a primeira camada da rede.
new_first_conv = torch.nn.Conv2d(1, 64, kernel_size=3, padding=1)
# Replace the original first layer
vgg_16_model.features[0] = new_first_conv

# %%
# Vamos colocar o modelo em modo de avaliação.
vgg_16_model.eval()

# Criar o dataloader para iterar nos dados.
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False, num_workers=1)

# Validar dispositivo de treino.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Colocar modelo no dispositivo.
vgg_16_model.to(device)

# Vamos medir a performance do modelo sem o refinamento.
correct = 0
for batch_idx, (data, target) in enumerate(test_loader):
    # Coloando os dados nos dispositivos.
    data = data.to(device)
    target = target.to(device)

    # Processando os dados.
    output = vgg_16_model(data)
    if target == torch.argmax(torch.softmax(output, dim=1)):
        correct = correct + 1

# Calcula acurácia.
acc = correct/len(test_data)
print(f"Acurácia com modelo sem refinamento: {acc * 100}%")
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1309 try:
# -> 1310     data = self._data_queue.get(timeout=timeout)
#    1311     return (True, data)
#
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\multiprocessing\queues.py:112, in Queue.get(self, block, timeout)
#     111     if not self._poll(timeout):
# --> 112         raise Empty
#     113 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 15
#      13 # Vamos medir a performance do modelo sem o refinamento.
#      14 correct = 0
# ---> 15 for batch_idx, (data, target) in enumerate(test_loader):
#      16     # Coloando os dados nos dispositivos.
#      17     data = data.to(device)
#      18     target = target.to(device)
#
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages\torch\utils\data\dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages\torch\utils\data\dataloader.py:1483, in _MultiProcessingDataLoaderIter._get_data(self)
#    1479     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1480     # need to call `.task_done()` because we don't use `.join()`.
#    1481 else:
#    1482     while True:
# -> 1483         success, data = self._try_get_data()
#    1484         if success:
#    1485             return data
#
# File c:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages\torch\utils\data\dataloader.py:1323, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1321 if len(failed_workers) > 0:
#    1322     pids_str = ", ".join(str(w.pid) for w in failed_workers)
# -> 1323     raise RuntimeError(
#    1324         f"DataLoader worker (pid(s) {pids_str}) exited unexpectedly"
#    1325     ) from e
#    1326 if isinstance(e, queue.Empty):
#    1327     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 33076) exited unexpectedly

# %%
########################
## Processo de treino. ##
########################

# Criando otimizador.
optimizer = torch.optim.SGD(vgg_16_model.parameters(), lr=0.0001)

# Definindo função de perda.
loss_criterion = torch.nn.CrossEntropyLoss()

# Criar o dataloader de treino.
batch_size = 16 # Define quantas instâncias serão processadas em uma passada do modelo.
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)

# Laço de treinamento.
epochs = 1
for epoch in range(epochs):
    # Colocar modelo em modo de treino.
    vgg_16_model.train()

    # Colocar modelo no dispositivo.
    vgg_16_model.to(device)
    
    # Função de perda e Acurácia para epóca.
    train_loss = 0.0
    train_acc = 0.0
    for batch_idx, (inputs, labels) in enumerate(train_loader):
        # Move os dados para o dispositivo de computação.
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Limpando os gradientes do otimizador.
        optimizer.zero_grad()

        # Passando informação no modelo.
        outputs = vgg_16_model(inputs)
        
        # Calculando a função de perda.
        loss = loss_criterion(outputs, labels)

        # Backpropagation dos gradientes.
        loss.backward()

        # Atualização dos parâmetros.
        optimizer.step()

        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
        
        # Calcule a acurácia.
        _, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
        
        # Calcular a acurácia do batch.
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
        
        # Calcular a acurácia total.
        train_acc += acc.item() * inputs.size(0)
        print("Batch number: {:03d}/{:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(batch_idx, len(train_data) // batch_size, loss.item(), acc.item()))
# Out:
# Batch number: 000/3750, Training: Loss: 2.3683, Accuracy: 0.0625
# Batch number: 001/3750, Training: Loss: 2.4069, Accuracy: 0.0625
# Batch number: 002/3750, Training: Loss: 2.2526, Accuracy: 0.1250
# Batch number: 003/3750, Training: Loss: 2.4060, Accuracy: 0.0000
# Batch number: 004/3750, Training: Loss: 2.3372, Accuracy: 0.1875
# Batch number: 005/3750, Training: Loss: 2.2368, Accuracy: 0.1875
# Batch number: 006/3750, Training: Loss: 2.2772, Accuracy: 0.2500
# Batch number: 007/3750, Training: Loss: 2.2069, Accuracy: 0.1250
# Batch number: 008/3750, Training: Loss: 2.3905, Accuracy: 0.0625
# Batch number: 009/3750, Training: Loss: 2.2729, Accuracy: 0.2500
# Batch number: 010/3750, Training: Loss: 2.3123, Accuracy: 0.1250
# Batch number: 011/3750, Training: Loss: 2.3533, Accuracy: 0.0625
# Batch number: 012/3750, Training: Loss: 2.3296, Accuracy: 0.0625
# Batch number: 013/3750, Training: Loss: 2.4343, Accuracy: 0.0625
# Batch number: 014/3750, Training: Loss: 2.3461, Accuracy: 0.0625
# Batch number: 015/3750, Training: Loss: 2.4138, Accuracy: 0.0000
# Batch number: 016/3750, Training: Loss: 2.3646, Accuracy: 0.1250
# Batch number: 017/3750, Training: Loss: 2.4156, Accuracy: 0.0000
# Batch number: 018/3750, Training: Loss: 2.2984, Accuracy: 0.0000
# Batch number: 019/3750, Training: Loss: 2.4663, Accuracy: 0.0000
# Batch number: 020/3750, Training: Loss: 2.2617, Accuracy: 0.1250
# Batch number: 554/3750, Training: Loss: 2.3227, Accuracy: 0.0000
# Batch number: 555/3750, Training: Loss: 2.2081, Accuracy: 0.2500
# Batch number: 556/3750, Training: Loss: 2.2356, Accuracy: 0.1875
# Batch number: 557/3750, Training: Loss: 2.2894, Accuracy: 0.0625
# Batch number: 558/3750, Training: Loss: 2.2787, Accuracy: 0.0625
# Batch number: 559/3750, Training: Loss: 2.2803, Accuracy: 0.0000
# Batch number: 560/3750, Training: Loss: 2.2181, Accuracy: 0.3125
# Batch number: 561/3750, Training: Loss: 2.2902, Accuracy: 0.1250
# Batch number: 562/3750, Training: Loss: 2.2625, Accuracy: 0.1875
# Batch number: 563/3750, Training: Loss: 2.2633, Accuracy: 0.0625
# Batch number: 564/3750, Training: Loss: 2.2585, Accuracy: 0.1250
# Batch number: 565/3750, Training: Loss: 2.2355, Accuracy: 0.1875
# Batch number: 566/3750, Training: Loss: 2.3357, Accuracy: 0.1250
# Batch number: 567/3750, Training: Loss: 2.1509, Accuracy: 0.2500
# Batch number: 568/3750, Training: Loss: 2.2756, Accuracy: 0.2500
# Batch number: 569/3750, Training: Loss: 2.2544, Accuracy: 0.1250
# Batch number: 570/3750, Training: Loss: 2.1344, Accuracy: 0.3125
# Batch number: 571/3750, Training: Loss: 2.2639, Accuracy: 0.1250
# Batch number: 572/3750, Training: Loss: 2.3370, Accuracy: 0.0000
# Batch number: 573/3750, Training: Loss: 2.1634, Accuracy: 0.2500
# Batch number: 574/3750, Training: Loss: 2.2326, Accuracy: 0.1250
# Batch number: 575/3750, Training: Loss: 2.2598, Accuracy: 0.1250
# Batch number: 576/3750, Training: Loss: 2.3388, Accuracy: 0.2500
# Batch number: 577/3750, Training: Loss: 2.3287, Accuracy: 0.0000
# Batch number: 578/3750, Training: Loss: 2.2472, Accuracy: 0.1250
# Batch number: 579/3750, Training: Loss: 2.1719, Accuracy: 0.3125
# Batch number: 580/3750, Training: Loss: 2.2405, Accuracy: 0.2500
# Batch number: 581/3750, Training: Loss: 2.2371, Accuracy: 0.3125
# Batch number: 582/3750, Training: Loss: 2.2256, Accuracy: 0.2500
# Batch number: 583/3750, Training: Loss: 2.2369, Accuracy: 0.3125
# Batch number: 584/3750, Training: Loss: 2.1899, Accuracy: 0.2500
# Batch number: 585/3750, Training: Loss: 2.1506, Accuracy: 0.4375
# Batch number: 586/3750, Training: Loss: 2.2243, Accuracy: 0.2500
# Batch number: 587/3750, Training: Loss: 2.2643, Accuracy: 0.1250
# Batch number: 588/3750, Training: Loss: 2.2396, Accuracy: 0.1250
# Batch number: 589/3750, Training: Loss: 2.1561, Accuracy: 0.3125
# Batch number: 590/3750, Training: Loss: 2.2479, Accuracy: 0.0625
# Batch number: 591/3750, Training: Loss: 2.1219, Accuracy: 0.3125
# Batch number: 592/3750, Training: Loss: 2.2725, Accuracy: 0.0625
# Batch number: 593/3750, Training: Loss: 2.3524, Accuracy: 0.0625
# Batch number: 594/3750, Training: Loss: 2.2346, Accuracy: 0.1875
# Batch number: 595/3750, Training: Loss: 2.3094, Accuracy: 0.0000
# Batch number: 596/3750, Training: Loss: 2.2365, Accuracy: 0.1875
# Batch number: 597/3750, Training: Loss: 2.3378, Accuracy: 0.0000
# Batch number: 598/3750, Training: Loss: 2.2599, Accuracy: 0.1250
# Batch number: 599/3750, Training: Loss: 2.3035, Accuracy: 0.0625
# Batch number: 600/3750, Training: Loss: 2.3032, Accuracy: 0.1250
# Batch number: 601/3750, Training: Loss: 2.1892, Accuracy: 0.1875
# Batch number: 602/3750, Training: Loss: 2.2528, Accuracy: 0.2500
# Batch number: 603/3750, Training: Loss: 2.2292, Accuracy: 0.1250
# Batch number: 604/3750, Training: Loss: 2.3166, Accuracy: 0.1875
# Batch number: 605/3750, Training: Loss: 2.2103, Accuracy: 0.1875
# Batch number: 606/3750, Training: Loss: 2.1134, Accuracy: 0.5625
# Batch number: 607/3750, Training: Loss: 2.2088, Accuracy: 0.2500
# Batch number: 608/3750, Training: Loss: 2.2689, Accuracy: 0.1250
# Batch number: 609/3750, Training: Loss: 2.3251, Accuracy: 0.1250
# Batch number: 610/3750, Training: Loss: 2.1955, Accuracy: 0.2500
# Batch number: 611/3750, Training: Loss: 2.2262, Accuracy: 0.0625
# Batch number: 612/3750, Training: Loss: 2.1575, Accuracy: 0.3125
# Batch number: 613/3750, Training: Loss: 2.2722, Accuracy: 0.1250
# Batch number: 614/3750, Training: Loss: 2.3002, Accuracy: 0.1250
# Batch number: 615/3750, Training: Loss: 2.2134, Accuracy: 0.1250
# Batch number: 616/3750, Training: Loss: 2.1813, Accuracy: 0.1875
# Batch number: 617/3750, Training: Loss: 2.2292, Accuracy: 0.1250
# Batch number: 618/3750, Training: Loss: 2.2863, Accuracy: 0.1875
# Batch number: 619/3750, Training: Loss: 2.2126, Accuracy: 0.2500
# Batch number: 620/3750, Training: Loss: 2.1961, Accuracy: 0.3125
# Batch number: 621/3750, Training: Loss: 2.1905, Accuracy: 0.2500
# Batch number: 622/3750, Training: Loss: 2.1930, Accuracy: 0.1250
# Batch number: 623/3750, Training: Loss: 2.2541, Accuracy: 0.1875
# Batch number: 624/3750, Training: Loss: 2.3049, Accuracy: 0.0625
# Batch number: 625/3750, Training: Loss: 2.1519, Accuracy: 0.2500
# Batch number: 626/3750, Training: Loss: 2.1950, Accuracy: 0.3750
# Batch number: 627/3750, Training: Loss: 2.2942, Accuracy: 0.1250
# Batch number: 628/3750, Training: Loss: 2.3004, Accuracy: 0.0000
# Batch number: 629/3750, Training: Loss: 2.1696, Accuracy: 0.2500
# Batch number: 630/3750, Training: Loss: 2.2680, Accuracy: 0.1250
# Batch number: 631/3750, Training: Loss: 2.2474, Accuracy: 0.1250
# Batch number: 632/3750, Training: Loss: 2.3054, Accuracy: 0.0625
# Batch number: 633/3750, Training: Loss: 2.2118, Accuracy: 0.1875
# Batch number: 634/3750, Training: Loss: 2.2051, Accuracy: 0.2500
# Batch number: 635/3750, Training: Loss: 2.2442, Accuracy: 0.1250
# Batch number: 636/3750, Training: Loss: 2.3248, Accuracy: 0.1875
# Batch number: 637/3750, Training: Loss: 2.2621, Accuracy: 0.1875
# Batch number: 638/3750, Training: Loss: 2.2271, Accuracy: 0.1875
# Batch number: 639/3750, Training: Loss: 2.2576, Accuracy: 0.1250
# Batch number: 640/3750, Training: Loss: 2.2026, Accuracy: 0.1875
# Batch number: 641/3750, Training: Loss: 2.2887, Accuracy: 0.0625
# Batch number: 642/3750, Training: Loss: 2.3439, Accuracy: 0.1250
# Batch number: 643/3750, Training: Loss: 2.2985, Accuracy: 0.0625
# Batch number: 644/3750, Training: Loss: 2.2590, Accuracy: 0.0625
# Batch number: 645/3750, Training: Loss: 2.2642, Accuracy: 0.2500
# Batch number: 646/3750, Training: Loss: 2.1354, Accuracy: 0.3750
# Batch number: 647/3750, Training: Loss: 2.2028, Accuracy: 0.2500
# Batch number: 648/3750, Training: Loss: 2.2528, Accuracy: 0.1875
# Batch number: 649/3750, Training: Loss: 2.2342, Accuracy: 0.1250
# Batch number: 650/3750, Training: Loss: 2.1296, Accuracy: 0.3125
# Batch number: 651/3750, Training: Loss: 2.2078, Accuracy: 0.3125
# Batch number: 652/3750, Training: Loss: 2.2576, Accuracy: 0.3125
# Batch number: 653/3750, Training: Loss: 2.2907, Accuracy: 0.1250
# Batch number: 654/3750, Training: Loss: 2.2189, Accuracy: 0.3125
# Batch number: 655/3750, Training: Loss: 2.3070, Accuracy: 0.0625
# Batch number: 656/3750, Training: Loss: 2.1899, Accuracy: 0.2500
# Batch number: 657/3750, Training: Loss: 2.2688, Accuracy: 0.1875
# Batch number: 658/3750, Training: Loss: 2.2986, Accuracy: 0.1250
# Batch number: 659/3750, Training: Loss: 2.2303, Accuracy: 0.0625
# Batch number: 660/3750, Training: Loss: 2.2487, Accuracy: 0.1875
# Batch number: 661/3750, Training: Loss: 2.1687, Accuracy: 0.4375
# Batch number: 662/3750, Training: Loss: 2.2313, Accuracy: 0.1875
# Batch number: 663/3750, Training: Loss: 2.2864, Accuracy: 0.2500
# Batch number: 664/3750, Training: Loss: 2.2391, Accuracy: 0.1875
# Batch number: 665/3750, Training: Loss: 2.2079, Accuracy: 0.1250
# Batch number: 666/3750, Training: Loss: 2.2460, Accuracy: 0.1875
# Batch number: 667/3750, Training: Loss: 2.1559, Accuracy: 0.3125
# Batch number: 668/3750, Training: Loss: 2.2129, Accuracy: 0.1250
# Batch number: 669/3750, Training: Loss: 2.1768, Accuracy: 0.2500
# Batch number: 670/3750, Training: Loss: 2.2351, Accuracy: 0.1250
# Batch number: 671/3750, Training: Loss: 2.2822, Accuracy: 0.1250
# Batch number: 672/3750, Training: Loss: 2.2479, Accuracy: 0.0625
# Batch number: 673/3750, Training: Loss: 2.3151, Accuracy: 0.0000
# Batch number: 674/3750, Training: Loss: 2.2459, Accuracy: 0.1250
# Batch number: 675/3750, Training: Loss: 2.1628, Accuracy: 0.2500
# Batch number: 676/3750, Training: Loss: 2.2573, Accuracy: 0.1875
# Batch number: 677/3750, Training: Loss: 2.3304, Accuracy: 0.0625
# Batch number: 678/3750, Training: Loss: 2.1823, Accuracy: 0.3125
# Batch number: 679/3750, Training: Loss: 2.1375, Accuracy: 0.3750
# Batch number: 680/3750, Training: Loss: 2.2760, Accuracy: 0.1875
# Batch number: 681/3750, Training: Loss: 2.2916, Accuracy: 0.1250
# Batch number: 682/3750, Training: Loss: 2.1708, Accuracy: 0.3125
# Batch number: 683/3750, Training: Loss: 2.2281, Accuracy: 0.1875
# Batch number: 684/3750, Training: Loss: 2.2121, Accuracy: 0.1875
# Batch number: 685/3750, Training: Loss: 2.1794, Accuracy: 0.2500
# Batch number: 686/3750, Training: Loss: 2.2245, Accuracy: 0.1875
# Batch number: 687/3750, Training: Loss: 2.2371, Accuracy: 0.0000
# Batch number: 688/3750, Training: Loss: 2.1492, Accuracy: 0.4375
# Batch number: 689/3750, Training: Loss: 2.1593, Accuracy: 0.3125
# Batch number: 690/3750, Training: Loss: 2.2318, Accuracy: 0.2500
# Batch number: 691/3750, Training: Loss: 2.2036, Accuracy: 0.2500
# Batch number: 692/3750, Training: Loss: 2.2298, Accuracy: 0.1250
# Batch number: 693/3750, Training: Loss: 2.2139, Accuracy: 0.0000
# Batch number: 694/3750, Training: Loss: 2.3307, Accuracy: 0.1250
# Batch number: 695/3750, Training: Loss: 2.2577, Accuracy: 0.0625
# Batch number: 696/3750, Training: Loss: 2.2926, Accuracy: 0.1875
# Batch number: 697/3750, Training: Loss: 2.2185, Accuracy: 0.2500
# Batch number: 698/3750, Training: Loss: 2.1852, Accuracy: 0.1875
# Batch number: 699/3750, Training: Loss: 2.2324, Accuracy: 0.1250
# Batch number: 700/3750, Training: Loss: 2.1833, Accuracy: 0.2500
# Batch number: 701/3750, Training: Loss: 2.1408, Accuracy: 0.3125
# Batch number: 702/3750, Training: Loss: 2.2373, Accuracy: 0.0625
# Batch number: 703/3750, Training: Loss: 2.2242, Accuracy: 0.2500
# Batch number: 704/3750, Training: Loss: 2.2970, Accuracy: 0.0000
# Batch number: 705/3750, Training: Loss: 2.1796, Accuracy: 0.1875
# Batch number: 706/3750, Training: Loss: 2.3066, Accuracy: 0.0625
# Batch number: 707/3750, Training: Loss: 2.2641, Accuracy: 0.0625
# Batch number: 708/3750, Training: Loss: 2.2126, Accuracy: 0.0625
# Batch number: 709/3750, Training: Loss: 2.2537, Accuracy: 0.1250
# Batch number: 710/3750, Training: Loss: 2.1827, Accuracy: 0.2500
# Batch number: 711/3750, Training: Loss: 2.2814, Accuracy: 0.1250
# Batch number: 712/3750, Training: Loss: 2.3373, Accuracy: 0.0625
# Batch number: 713/3750, Training: Loss: 2.2261, Accuracy: 0.0625
# Batch number: 714/3750, Training: Loss: 2.2199, Accuracy: 0.1250
# Batch number: 715/3750, Training: Loss: 2.2343, Accuracy: 0.1250
# Batch number: 716/3750, Training: Loss: 2.1755, Accuracy: 0.2500
# Batch number: 717/3750, Training: Loss: 2.1610, Accuracy: 0.3125
# Batch number: 718/3750, Training: Loss: 2.1889, Accuracy: 0.1875
# Batch number: 719/3750, Training: Loss: 2.2396, Accuracy: 0.1875
# Batch number: 720/3750, Training: Loss: 2.1882, Accuracy: 0.3750
# Batch number: 721/3750, Training: Loss: 2.3315, Accuracy: 0.1250
# Batch number: 722/3750, Training: Loss: 2.1910, Accuracy: 0.1250
# Batch number: 723/3750, Training: Loss: 2.2549, Accuracy: 0.2500
# Batch number: 724/3750, Training: Loss: 2.2577, Accuracy: 0.2500
# Batch number: 725/3750, Training: Loss: 2.2208, Accuracy: 0.3125
# Batch number: 726/3750, Training: Loss: 2.2310, Accuracy: 0.0625
# Batch number: 727/3750, Training: Loss: 2.2321, Accuracy: 0.3125
# Batch number: 728/3750, Training: Loss: 2.2096, Accuracy: 0.1875
# Batch number: 729/3750, Training: Loss: 2.2700, Accuracy: 0.1250
# Batch number: 730/3750, Training: Loss: 2.1472, Accuracy: 0.2500
# Batch number: 731/3750, Training: Loss: 2.2511, Accuracy: 0.0625
# Batch number: 732/3750, Training: Loss: 2.2512, Accuracy: 0.1875
# Batch number: 733/3750, Training: Loss: 2.2017, Accuracy: 0.2500
# Batch number: 734/3750, Training: Loss: 2.2860, Accuracy: 0.0625
# Batch number: 735/3750, Training: Loss: 2.1487, Accuracy: 0.3750
# Batch number: 736/3750, Training: Loss: 2.1445, Accuracy: 0.4375
# Batch number: 737/3750, Training: Loss: 2.2856, Accuracy: 0.1875
# ...
# Batch number: 3508/3750, Training: Loss: 0.5335, Accuracy: 0.8125
# Batch number: 3509/3750, Training: Loss: 0.3314, Accuracy: 0.8750
# Batch number: 3510/3750, Training: Loss: 0.2167, Accuracy: 1.0000
# Batch number: 3511/3750, Training: Loss: 0.4477, Accuracy: 0.8750
# Batch number: 3512/3750, Training: Loss: 0.2723, Accuracy: 0.9375
# Batch number: 3513/3750, Training: Loss: 0.1526, Accuracy: 1.0000
# Batch number: 3514/3750, Training: Loss: 0.1880, Accuracy: 1.0000
# Batch number: 3515/3750, Training: Loss: 0.2468, Accuracy: 0.9375
# Batch number: 3516/3750, Training: Loss: 0.2532, Accuracy: 0.8750
# Batch number: 3517/3750, Training: Loss: 0.2059, Accuracy: 0.9375
# Batch number: 3518/3750, Training: Loss: 0.3058, Accuracy: 0.8750
# Batch number: 3519/3750, Training: Loss: 0.0659, Accuracy: 1.0000
# Batch number: 3520/3750, Training: Loss: 0.6380, Accuracy: 0.8125
# Batch number: 3521/3750, Training: Loss: 0.1984, Accuracy: 0.9375
# Batch number: 3522/3750, Training: Loss: 0.1270, Accuracy: 1.0000
# Batch number: 3523/3750, Training: Loss: 0.2295, Accuracy: 0.9375
# Batch number: 3524/3750, Training: Loss: 0.6096, Accuracy: 0.7500
# Batch number: 3525/3750, Training: Loss: 0.2195, Accuracy: 1.0000
# Batch number: 3526/3750, Training: Loss: 0.0954, Accuracy: 1.0000
# Batch number: 3527/3750, Training: Loss: 0.2031, Accuracy: 1.0000
# Batch number: 3528/3750, Training: Loss: 0.4038, Accuracy: 0.8750
# Batch number: 3529/3750, Training: Loss: 0.4820, Accuracy: 0.8750
# Batch number: 3530/3750, Training: Loss: 0.3001, Accuracy: 0.8125
# Batch number: 3531/3750, Training: Loss: 0.5421, Accuracy: 0.8125
# Batch number: 3532/3750, Training: Loss: 0.3854, Accuracy: 0.8750
# Batch number: 3533/3750, Training: Loss: 0.3590, Accuracy: 0.9375
# Batch number: 3534/3750, Training: Loss: 0.1827, Accuracy: 0.9375
# Batch number: 3535/3750, Training: Loss: 0.2282, Accuracy: 0.8750
# Batch number: 3536/3750, Training: Loss: 0.2743, Accuracy: 0.7500
# Batch number: 3537/3750, Training: Loss: 0.5561, Accuracy: 0.8750
# Batch number: 3538/3750, Training: Loss: 0.2881, Accuracy: 0.9375
# Batch number: 3539/3750, Training: Loss: 0.3364, Accuracy: 0.8750
# Batch number: 3540/3750, Training: Loss: 0.4489, Accuracy: 0.8125
# Batch number: 3541/3750, Training: Loss: 0.2602, Accuracy: 0.8750
# Batch number: 3542/3750, Training: Loss: 0.6802, Accuracy: 0.8125
# Batch number: 3543/3750, Training: Loss: 0.5146, Accuracy: 0.9375
# Batch number: 3544/3750, Training: Loss: 0.1190, Accuracy: 1.0000
# Batch number: 3545/3750, Training: Loss: 0.0758, Accuracy: 1.0000
# Batch number: 3546/3750, Training: Loss: 0.2215, Accuracy: 0.9375
# Batch number: 3547/3750, Training: Loss: 0.3406, Accuracy: 0.8750
# Batch number: 3548/3750, Training: Loss: 0.2464, Accuracy: 1.0000
# Batch number: 3549/3750, Training: Loss: 0.3538, Accuracy: 0.8125
# Batch number: 3550/3750, Training: Loss: 0.3118, Accuracy: 0.8750
# Batch number: 3551/3750, Training: Loss: 0.2923, Accuracy: 0.9375
# Batch number: 3552/3750, Training: Loss: 0.2149, Accuracy: 0.9375
# Batch number: 3553/3750, Training: Loss: 0.0960, Accuracy: 1.0000
# Batch number: 3554/3750, Training: Loss: 0.3840, Accuracy: 0.8750
# Batch number: 3555/3750, Training: Loss: 0.7423, Accuracy: 0.7500
# Batch number: 3556/3750, Training: Loss: 0.1396, Accuracy: 1.0000
# Batch number: 3557/3750, Training: Loss: 0.1907, Accuracy: 1.0000
# Batch number: 3558/3750, Training: Loss: 0.3819, Accuracy: 0.9375
# Batch number: 3559/3750, Training: Loss: 0.2645, Accuracy: 1.0000
# Batch number: 3560/3750, Training: Loss: 0.5175, Accuracy: 0.9375
# Batch number: 3561/3750, Training: Loss: 0.2334, Accuracy: 1.0000
# Batch number: 3562/3750, Training: Loss: 0.2729, Accuracy: 0.8750
# Batch number: 3563/3750, Training: Loss: 0.1746, Accuracy: 1.0000
# Batch number: 3564/3750, Training: Loss: 1.2367, Accuracy: 0.6875
# Batch number: 3565/3750, Training: Loss: 0.2694, Accuracy: 0.8750
# Batch number: 3566/3750, Training: Loss: 0.3163, Accuracy: 0.8750
# Batch number: 3567/3750, Training: Loss: 0.4877, Accuracy: 0.8125
# Batch number: 3568/3750, Training: Loss: 0.2633, Accuracy: 0.8750
# Batch number: 3569/3750, Training: Loss: 0.1841, Accuracy: 0.9375
# Batch number: 3570/3750, Training: Loss: 0.1450, Accuracy: 1.0000
# Batch number: 3571/3750, Training: Loss: 0.4347, Accuracy: 0.8125
# Batch number: 3572/3750, Training: Loss: 1.2050, Accuracy: 0.6250
# Batch number: 3573/3750, Training: Loss: 0.4676, Accuracy: 0.8750
# Batch number: 3574/3750, Training: Loss: 0.2430, Accuracy: 0.9375
# Batch number: 3575/3750, Training: Loss: 0.4795, Accuracy: 0.7500
# Batch number: 3576/3750, Training: Loss: 0.0899, Accuracy: 1.0000
# Batch number: 3577/3750, Training: Loss: 0.1613, Accuracy: 0.9375
# Batch number: 3578/3750, Training: Loss: 0.5402, Accuracy: 0.8125
# Batch number: 3579/3750, Training: Loss: 0.2097, Accuracy: 0.9375
# Batch number: 3580/3750, Training: Loss: 0.4507, Accuracy: 0.8750
# Batch number: 3581/3750, Training: Loss: 0.4780, Accuracy: 0.8750
# Batch number: 3582/3750, Training: Loss: 0.2820, Accuracy: 0.9375
# Batch number: 3583/3750, Training: Loss: 0.2787, Accuracy: 0.9375
# Batch number: 3584/3750, Training: Loss: 0.3567, Accuracy: 0.8750
# Batch number: 3585/3750, Training: Loss: 0.0912, Accuracy: 1.0000
# Batch number: 3586/3750, Training: Loss: 0.3834, Accuracy: 0.8125
# Batch number: 3587/3750, Training: Loss: 0.7808, Accuracy: 0.7500
# Batch number: 3588/3750, Training: Loss: 0.2472, Accuracy: 0.9375
# Batch number: 3589/3750, Training: Loss: 0.0828, Accuracy: 1.0000
# Batch number: 3590/3750, Training: Loss: 0.6648, Accuracy: 0.8125
# Batch number: 3591/3750, Training: Loss: 0.3991, Accuracy: 0.9375
# Batch number: 3592/3750, Training: Loss: 0.1865, Accuracy: 0.9375
# Batch number: 3593/3750, Training: Loss: 0.9495, Accuracy: 0.6250
# Batch number: 3594/3750, Training: Loss: 0.1578, Accuracy: 0.9375
# Batch number: 3595/3750, Training: Loss: 0.4033, Accuracy: 0.8750
# Batch number: 3596/3750, Training: Loss: 0.3032, Accuracy: 0.9375
# Batch number: 3597/3750, Training: Loss: 0.3598, Accuracy: 0.8125
# Batch number: 3598/3750, Training: Loss: 0.5308, Accuracy: 0.9375
# Batch number: 3599/3750, Training: Loss: 0.5855, Accuracy: 0.7500
# Batch number: 3600/3750, Training: Loss: 0.8188, Accuracy: 0.7500
# Batch number: 3601/3750, Training: Loss: 0.2026, Accuracy: 1.0000
# Batch number: 3602/3750, Training: Loss: 0.3640, Accuracy: 0.8750
# Batch number: 3603/3750, Training: Loss: 0.4595, Accuracy: 0.8125
# Batch number: 3604/3750, Training: Loss: 0.2991, Accuracy: 0.9375
# Batch number: 3605/3750, Training: Loss: 0.2672, Accuracy: 0.8750
# Batch number: 3606/3750, Training: Loss: 0.2088, Accuracy: 0.9375
# Batch number: 3607/3750, Training: Loss: 0.2638, Accuracy: 1.0000
# Batch number: 3608/3750, Training: Loss: 0.1378, Accuracy: 1.0000
# Batch number: 3609/3750, Training: Loss: 0.3789, Accuracy: 0.9375
# Batch number: 3610/3750, Training: Loss: 0.2220, Accuracy: 0.9375
# Batch number: 3611/3750, Training: Loss: 0.2304, Accuracy: 0.8750
# Batch number: 3612/3750, Training: Loss: 0.4454, Accuracy: 0.8125
# Batch number: 3613/3750, Training: Loss: 0.2644, Accuracy: 0.8750
# Batch number: 3614/3750, Training: Loss: 0.2720, Accuracy: 0.9375
# Batch number: 3615/3750, Training: Loss: 0.1665, Accuracy: 0.9375
# Batch number: 3616/3750, Training: Loss: 0.0334, Accuracy: 1.0000
# Batch number: 3617/3750, Training: Loss: 0.5147, Accuracy: 0.8750
# Batch number: 3618/3750, Training: Loss: 0.3561, Accuracy: 0.8750
# Batch number: 3619/3750, Training: Loss: 0.2870, Accuracy: 0.9375
# Batch number: 3620/3750, Training: Loss: 0.1772, Accuracy: 1.0000
# Batch number: 3621/3750, Training: Loss: 0.2066, Accuracy: 0.9375
# Batch number: 3622/3750, Training: Loss: 0.6999, Accuracy: 0.8750
# Batch number: 3623/3750, Training: Loss: 0.9083, Accuracy: 0.6250
# Batch number: 3624/3750, Training: Loss: 0.2360, Accuracy: 0.8750
# Batch number: 3625/3750, Training: Loss: 0.2888, Accuracy: 0.9375
# Batch number: 3626/3750, Training: Loss: 0.6117, Accuracy: 0.8125
# Batch number: 3627/3750, Training: Loss: 0.1244, Accuracy: 1.0000
# Batch number: 3628/3750, Training: Loss: 0.2110, Accuracy: 0.9375
# Batch number: 3629/3750, Training: Loss: 0.2796, Accuracy: 0.9375
# Batch number: 3630/3750, Training: Loss: 0.5387, Accuracy: 0.8125
# Batch number: 3631/3750, Training: Loss: 0.2429, Accuracy: 0.9375
# Batch number: 3632/3750, Training: Loss: 0.4867, Accuracy: 0.9375
# Batch number: 3633/3750, Training: Loss: 0.1879, Accuracy: 1.0000
# Batch number: 3634/3750, Training: Loss: 0.4149, Accuracy: 0.8125
# Batch number: 3635/3750, Training: Loss: 0.4887, Accuracy: 0.8750
# Batch number: 3636/3750, Training: Loss: 0.3034, Accuracy: 0.8750
# Batch number: 3637/3750, Training: Loss: 0.2223, Accuracy: 0.9375
# Batch number: 3638/3750, Training: Loss: 0.2739, Accuracy: 0.9375
# Batch number: 3639/3750, Training: Loss: 0.2077, Accuracy: 0.8750
# Batch number: 3640/3750, Training: Loss: 1.0577, Accuracy: 0.6250
# Batch number: 3641/3750, Training: Loss: 0.1128, Accuracy: 0.9375
# Batch number: 3642/3750, Training: Loss: 0.4676, Accuracy: 0.7500
# Batch number: 3643/3750, Training: Loss: 0.2424, Accuracy: 0.8750
# Batch number: 3644/3750, Training: Loss: 0.8208, Accuracy: 0.6875
# Batch number: 3645/3750, Training: Loss: 0.8029, Accuracy: 0.7500
# Batch number: 3646/3750, Training: Loss: 0.2372, Accuracy: 0.9375
# Batch number: 3647/3750, Training: Loss: 0.1302, Accuracy: 0.9375
# Batch number: 3648/3750, Training: Loss: 0.4684, Accuracy: 0.8750
# Batch number: 3649/3750, Training: Loss: 0.1455, Accuracy: 0.9375
# Batch number: 3650/3750, Training: Loss: 0.3446, Accuracy: 0.8125
# Batch number: 3651/3750, Training: Loss: 0.3652, Accuracy: 0.8750
# Batch number: 3652/3750, Training: Loss: 0.6047, Accuracy: 0.6875
# Batch number: 3653/3750, Training: Loss: 0.1369, Accuracy: 1.0000
# Batch number: 3654/3750, Training: Loss: 0.5816, Accuracy: 0.8125
# Batch number: 3655/3750, Training: Loss: 0.2838, Accuracy: 0.8750
# Batch number: 3656/3750, Training: Loss: 0.5374, Accuracy: 0.8750
# Batch number: 3657/3750, Training: Loss: 0.5129, Accuracy: 0.8750
# Batch number: 3658/3750, Training: Loss: 0.4368, Accuracy: 0.9375
# Batch number: 3659/3750, Training: Loss: 0.2586, Accuracy: 0.9375
# Batch number: 3660/3750, Training: Loss: 0.1731, Accuracy: 1.0000
# Batch number: 3661/3750, Training: Loss: 0.1718, Accuracy: 1.0000
# Batch number: 3662/3750, Training: Loss: 0.2996, Accuracy: 0.8750
# Batch number: 3663/3750, Training: Loss: 0.7151, Accuracy: 0.8125
# Batch number: 3664/3750, Training: Loss: 0.4490, Accuracy: 0.8125
# Batch number: 3665/3750, Training: Loss: 0.2115, Accuracy: 0.9375
# Batch number: 3666/3750, Training: Loss: 0.1293, Accuracy: 0.9375
# Batch number: 3667/3750, Training: Loss: 0.1989, Accuracy: 1.0000
# Batch number: 3668/3750, Training: Loss: 0.3027, Accuracy: 0.9375
# Batch number: 3669/3750, Training: Loss: 0.0808, Accuracy: 1.0000
# Batch number: 3670/3750, Training: Loss: 0.0873, Accuracy: 1.0000
# Batch number: 3671/3750, Training: Loss: 0.0798, Accuracy: 1.0000
# Batch number: 3672/3750, Training: Loss: 0.1132, Accuracy: 1.0000
# Batch number: 3673/3750, Training: Loss: 0.1010, Accuracy: 1.0000
# Batch number: 3674/3750, Training: Loss: 0.5249, Accuracy: 0.8125
# Batch number: 3675/3750, Training: Loss: 0.4886, Accuracy: 0.8750
# Batch number: 3676/3750, Training: Loss: 0.1004, Accuracy: 1.0000
# Batch number: 3677/3750, Training: Loss: 0.2946, Accuracy: 0.9375
# Batch number: 3678/3750, Training: Loss: 0.2304, Accuracy: 0.9375
# Batch number: 3679/3750, Training: Loss: 0.1466, Accuracy: 1.0000
# Batch number: 3680/3750, Training: Loss: 0.2748, Accuracy: 0.8750
# Batch number: 3681/3750, Training: Loss: 0.3048, Accuracy: 0.9375
# Batch number: 3682/3750, Training: Loss: 0.1639, Accuracy: 1.0000
# Batch number: 3683/3750, Training: Loss: 0.3819, Accuracy: 0.8750
# Batch number: 3684/3750, Training: Loss: 0.3988, Accuracy: 0.9375
# Batch number: 3685/3750, Training: Loss: 0.3720, Accuracy: 0.8125
# Batch number: 3686/3750, Training: Loss: 0.3078, Accuracy: 0.9375
# Batch number: 3687/3750, Training: Loss: 0.2101, Accuracy: 1.0000
# Batch number: 3688/3750, Training: Loss: 0.3863, Accuracy: 0.8750
# Batch number: 3689/3750, Training: Loss: 0.1526, Accuracy: 0.9375
# Batch number: 3690/3750, Training: Loss: 0.3857, Accuracy: 0.9375
# Batch number: 3691/3750, Training: Loss: 0.2718, Accuracy: 0.8750
# Batch number: 3692/3750, Training: Loss: 0.4704, Accuracy: 0.8125
# Batch number: 3693/3750, Training: Loss: 0.4053, Accuracy: 0.8750
# Batch number: 3694/3750, Training: Loss: 0.5367, Accuracy: 0.8750
# Batch number: 3695/3750, Training: Loss: 0.1813, Accuracy: 1.0000
# Batch number: 3696/3750, Training: Loss: 0.3626, Accuracy: 0.9375
# Batch number: 3697/3750, Training: Loss: 0.2219, Accuracy: 1.0000
# Batch number: 3698/3750, Training: Loss: 0.1864, Accuracy: 0.9375
# Batch number: 3699/3750, Training: Loss: 0.1642, Accuracy: 1.0000
# Batch number: 3700/3750, Training: Loss: 0.3353, Accuracy: 0.8750
# Batch number: 3701/3750, Training: Loss: 0.1751, Accuracy: 0.9375
# Batch number: 3702/3750, Training: Loss: 0.2817, Accuracy: 0.8750
# Batch number: 3703/3750, Training: Loss: 0.1965, Accuracy: 1.0000
# Batch number: 3704/3750, Training: Loss: 0.3145, Accuracy: 0.8750
# Batch number: 3705/3750, Training: Loss: 0.4253, Accuracy: 0.8125
# Batch number: 3706/3750, Training: Loss: 0.0388, Accuracy: 1.0000
# Batch number: 3707/3750, Training: Loss: 0.3090, Accuracy: 0.9375
# Batch number: 3708/3750, Training: Loss: 0.2774, Accuracy: 0.8750
# Batch number: 3709/3750, Training: Loss: 0.0661, Accuracy: 1.0000
# Batch number: 3710/3750, Training: Loss: 0.1281, Accuracy: 1.0000
# Batch number: 3711/3750, Training: Loss: 0.1642, Accuracy: 0.9375
# Batch number: 3712/3750, Training: Loss: 0.4956, Accuracy: 0.7500
# Batch number: 3713/3750, Training: Loss: 0.6253, Accuracy: 0.8125
# Batch number: 3714/3750, Training: Loss: 0.4067, Accuracy: 0.8125
# Batch number: 3715/3750, Training: Loss: 0.2595, Accuracy: 0.8750
# Batch number: 3716/3750, Training: Loss: 0.2735, Accuracy: 0.8750
# Batch number: 3717/3750, Training: Loss: 0.2469, Accuracy: 0.9375
# Batch number: 3718/3750, Training: Loss: 0.1085, Accuracy: 0.9375
# Batch number: 3719/3750, Training: Loss: 0.2683, Accuracy: 0.9375
# Batch number: 3720/3750, Training: Loss: 0.3569, Accuracy: 0.8125
# Batch number: 3721/3750, Training: Loss: 0.3149, Accuracy: 0.9375
# Batch number: 3722/3750, Training: Loss: 0.0829, Accuracy: 1.0000
# Batch number: 3723/3750, Training: Loss: 0.2034, Accuracy: 0.9375
# Batch number: 3724/3750, Training: Loss: 0.2054, Accuracy: 0.9375
# Batch number: 3725/3750, Training: Loss: 0.1339, Accuracy: 1.0000
# Batch number: 3726/3750, Training: Loss: 0.1776, Accuracy: 0.9375
# Batch number: 3727/3750, Training: Loss: 0.2429, Accuracy: 0.8750
# Batch number: 3728/3750, Training: Loss: 0.3151, Accuracy: 0.9375
# Batch number: 3729/3750, Training: Loss: 0.1805, Accuracy: 0.9375
# Batch number: 3730/3750, Training: Loss: 0.2170, Accuracy: 0.9375
# Batch number: 3731/3750, Training: Loss: 0.0587, Accuracy: 1.0000
# Batch number: 3732/3750, Training: Loss: 0.6150, Accuracy: 0.6875
# Batch number: 3733/3750, Training: Loss: 0.4564, Accuracy: 0.9375
# Batch number: 3734/3750, Training: Loss: 0.1582, Accuracy: 1.0000
# Batch number: 3735/3750, Training: Loss: 0.3165, Accuracy: 0.8750
# Batch number: 3736/3750, Training: Loss: 0.0919, Accuracy: 1.0000
# Batch number: 3737/3750, Training: Loss: 0.8160, Accuracy: 0.7500
# Batch number: 3738/3750, Training: Loss: 0.2091, Accuracy: 0.8750
# Batch number: 3739/3750, Training: Loss: 0.1644, Accuracy: 1.0000
# Batch number: 3740/3750, Training: Loss: 0.4401, Accuracy: 0.8750
# Batch number: 3741/3750, Training: Loss: 0.2167, Accuracy: 1.0000
# Batch number: 3742/3750, Training: Loss: 0.3875, Accuracy: 0.7500
# Batch number: 3743/3750, Training: Loss: 0.3326, Accuracy: 0.8750
# Batch number: 3744/3750, Training: Loss: 0.3319, Accuracy: 0.8125
# Batch number: 3745/3750, Training: Loss: 0.3546, Accuracy: 0.9375
# Batch number: 3746/3750, Training: Loss: 0.3947, Accuracy: 0.8750
# Batch number: 3747/3750, Training: Loss: 0.1087, Accuracy: 1.0000
# Batch number: 3748/3750, Training: Loss: 0.1312, Accuracy: 1.0000
# Batch number: 3749/3750, Training: Loss: 0.1890, Accuracy: 1.0000

# %%
# Vamos colocar o modelo em modo de avaliação.
vgg_16_model.eval()

# Criar o dataloader para iterar nos dados.
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False, num_workers=1)

# Vamos medir a performance do modelo sem o refinamento.
correct = 0
for batch_idx, (data, target) in enumerate(test_loader):
    # Coloando os dados nos dispositivos.
    data = data.to(device)
    target = target.to(device)

    # Processando os dados.
    output = vgg_16_model(data)
    if target == torch.argmax(torch.softmax(output, dim=1)):
        correct = correct + 1

# Calcula acurácia.
acc = correct/len(test_data)
print(f"Acurácia com modelo com refinamento: {acc * 100}%")
# Out:
# Acurácia com modelo com refinamento: 95.61%
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# E com isso terminamos a prática de hoje.

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos trasbalhar com problemas clássicos de Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://docs.pytorch.org/vision/0.8/datasets.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# - [ ] Altere os hiperparâmetros, como número de epocas, tamanho do batch e learning rate do otimizador.
# - [ ] Tente utilizar outro modelo pré-treinado da mesma forma que utilizamos o modelo VGG 16.
