# %% [markdown]
# # M4A5 - Fundamentos de Modelos Multimodais

# %% [markdown]
# Na prática de hoje vamos usar o modelo [CLIP](https://openai.com/index/clip/) da OpenAI.
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Utilizar o modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to C:\Users\joelr\AppData\Local\Temp\pip-req-build-xzd_jf1k
#   Resolved https://github.com/openai/CLIP.git to commit ded190a052fdf4585bd685cee5bc96e0310d2c93
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: ftfy in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (25.0)
# Requirement already satisfied: regex in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (2026.2.28)
# Requirement already satisfied: tqdm in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (4.67.3)
# Requirement already satisfied: torch in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from clip==1.0) (0.20.1+cu121)
# Requirement already satisfied: wcwidth in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from ftfy->clip==1.0) (0.6.0)
# Requirement already satisfied: filelock in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: networkx in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (2025.12.0)
# Requirement already satisfied: setuptools in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (80.10.2)
# Requirement already satisfied: sympy==1.13.1 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Requirement already satisfied: numpy in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torchvision->clip==1.0) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from torchvision->clip==1.0) (12.0.0)
# Requirement already satisfied: colorama in C:\Users\joelr\anaconda3\envs\computer_vision\Lib\site-packages (from tqdm->clip==1.0) (0.4.6)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\joelr\AppData\Local\Temp\pip-req-build-xzd_jf1k'

# %% [markdown]
# Importar as bibliotecas e Ler Imagens do Disco

# %%
import torch
import clip
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Utilizar o Modelo
#
# Para isso iremos instanciar o modelo do CLIP e utilizar com texto e imagens.

# %%
# Path para a imagem.
# path_image = r"images\rio.jpeg"
path_image = r"images\dog.jpeg"

# Textos para avaliar.
# texts = ["a statue", "the moutains", "the beach"]
texts = ["a cat", "a dog", "a diagram"]

# Define o dispositivo a carregar o modelo.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Carrega o modelo com o backbone do ViT-B/32.
model, preprocess = clip.load("ViT-B/32", device=device)


# Processa a imagem.
image = preprocess(Image.open(path_image)).unsqueeze(0).to(device)

# Processa o texto.
text = clip.tokenize(texts).to(device)

# Roda inferências.
with torch.no_grad():
    _ = model.encode_image(image) # Encoda imagem.
    _ = model.encode_text(text) # Encoda o texto.
    
    logits_per_image, logits_per_text = model(image, text) # Computa similaridade entre imagem e textos.
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()[0] # Retorna probabilidades.

formated_probs_str = '[' + ', '.join(f'{x * 100:.2f}% de "{t}"' for x, t in zip(list(probs), texts)) + ']'

plt.imshow(Image.open(path_image))
print(texts)
print("Probabilidades imagem vs. textos:", formated_probs_str)

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos trabalhar com problemas reais que envolvem Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://github.com/openai/CLIP
# - https://openai.com/index/clip/
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opcional)

# %% [markdown]
# - [ ] Tente utilizar outros dados imagens e textos.
# - [ ] Tente utilizar outro modelo base do CLIP. Details on https://github.com/openai/CLIP/blob/main/model-card.md#model-versions .
